# %%
import pandas as pd

# %%
hr_data=pd.read_csv("Uncleaned_employees_final_dataset.csv")
hr_data
# Out:
#        employee_id         department     region  education gender  \
# 0             8724         Technology  region_26  Bachelors      m
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17414        49584                 HR   region_7  Bachelors      m
# 17415        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24                   NaN
# ...

# %%
hr_data.isna().sum()
# Out:
# employee_id                 0
# department                  0
# region                      0
# education                 771
# gender                      0
# recruitment_channel         0
# no_of_trainings             0
# age                         0
# previous_year_rating     1363
# length_of_service           0
# KPIs_met_more_than_80       0
# awards_won                  0
# avg_training_score          0
# dtype: int64

# %% [markdown]
# ### Step 1: Removing duplicate rows

# %%
hr_data.loc[hr_data.duplicated(keep=False)]
# Out:
#        employee_id department    region  education gender recruitment_channel  \
# 17413        49584         HR  region_7  Bachelors      m               other
# 17414        49584         HR  region_7  Bachelors      m               other
# 17415        49584         HR  region_7  Bachelors      m               other
#
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# 17413                1   33                   1.0                  9
# 17414                1   33                   1.0                  9
# 17415                1   33                   1.0                  9
#
#        KPIs_met_more_than_80  awards_won  avg_training_score
# 17413                      0           0                  51
# 17414                      0           0                  51
# 17415                      0           0                  51

# %%
hr_data.drop_duplicates(keep='first', inplace=True)

# %%
hr_data.shape
# Out:
# (17415, 13)

# %% [markdown]
# ### Step 2: Removing rows for which numeric columns are having irrelevant data type values

# %%
hr_data.dtypes
# Out:
# employee_id                int64
# department                object
# region                    object
# education                 object
# gender                    object
# recruitment_channel       object
# no_of_trainings            int64
# age                        int64
# previous_year_rating     float64
# length_of_service          int64
# KPIs_met_more_than_80      int64
# awards_won                 int64
# avg_training_score         int64
# dtype: object

# %%
hr_data.head()
# Out:
#    employee_id         department     region  education gender  \
# 0         8724         Technology  region_26  Bachelors      m
# 1        74430                 HR   region_4  Bachelors      f
# 2        72255  Sales & Marketing  region_13  Bachelors      m
# 3        38562        Procurement   region_2  Bachelors      f
# 4        64486            Finance  region_29  Bachelors      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   NaN
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met_more_than_80  awards_won  avg_training_score
# 0                  1                      1           0                  77
# ...

# %% [markdown]
# ### Step 3: Remove irrelevant values from each column if any. Validation all values for a column, Check for any inconsistencies or discrepancies in data types, units, or formats.Feel free to add more validation checks which you might feel necessary for the dataset’s integrity

# %%
hr_data.isna().sum()
# Out:
# employee_id                 0
# department                  0
# region                      0
# education                 771
# gender                      0
# recruitment_channel         0
# no_of_trainings             0
# age                         0
# previous_year_rating     1363
# length_of_service           0
# KPIs_met_more_than_80       0
# awards_won                  0
# avg_training_score          0
# dtype: int64

# %%
hr_data.isnull().sum()
# Out:
# employee_id                 0
# department                  0
# region                      0
# education                 771
# gender                      0
# recruitment_channel         0
# no_of_trainings             0
# age                         0
# previous_year_rating     1363
# length_of_service           0
# KPIs_met_more_than_80       0
# awards_won                  0
# avg_training_score          0
# dtype: int64

# %%
hr_data_no_null=hr_data.fillna({'education':'Not available',
                               'previous_year_rating':0})
hr_data_no_null
# Out:
#        employee_id         department     region  education gender  \
# 0             8724         Technology  region_26  Bachelors      m
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17410        57239  Sales & Marketing  region_31  Bachelors      m
# 17411        73858  Sales & Marketing  region_25  Bachelors      m
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24                   0.0
# ...

# %%
hr_data_no_null.isna().sum()
# Out:
# employee_id              0
# department               0
# region                   0
# education                0
# gender                   0
# recruitment_channel      0
# no_of_trainings          0
# age                      0
# previous_year_rating     0
# length_of_service        0
# KPIs_met_more_than_80    0
# awards_won               0
# avg_training_score       0
# dtype: int64

# %%
hr_data.isna().sum()
# Out:
# employee_id                 0
# department                  0
# region                      0
# education                 771
# gender                      0
# recruitment_channel         0
# no_of_trainings             0
# age                         0
# previous_year_rating     1363
# length_of_service           0
# KPIs_met_more_than_80       0
# awards_won                  0
# avg_training_score          0
# dtype: int64

# %%
hr_data_no_null.isna().sum()
# Out:
# employee_id              0
# department               0
# region                   0
# education                0
# gender                   0
# recruitment_channel      0
# no_of_trainings          0
# age                      0
# previous_year_rating     0
# length_of_service        0
# KPIs_met_more_than_80    0
# awards_won               0
# avg_training_score       0
# dtype: int64

# %%
hr_data_no_null['education'].value_counts()
# Out:
# Bachelors          11517
# Masters & above     4841
# Not available        771
# Below Secondary      286
# Name: education, dtype: int64

# %%
hr_data_no_null['previous_year_rating'].value_counts()
# Out:
# 3.0    5813
# 5.0    3817
# 4.0    3156
# 1.0    1974
# 0.0    1363
# 2.0    1292
# Name: previous_year_rating, dtype: int64

# %%
Clean_hr_data=hr_data_no_null

# %%
Clean_hr_data
# Out:
#        employee_id         department     region  education gender  \
# 0             8724         Technology  region_26  Bachelors      m
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17410        57239  Sales & Marketing  region_31  Bachelors      m
# 17411        73858  Sales & Marketing  region_25  Bachelors      m
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24                   0.0
# ...

# %%
Clean_hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17415 entries, 0 to 17416
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            17415 non-null  int64
#  1   department             17415 non-null  object
#  2   region                 17415 non-null  object
#  3   education              17415 non-null  object
#  4   gender                 17415 non-null  object
#  5   recruitment_channel    17415 non-null  object
#  6   no_of_trainings        17415 non-null  int64
#  7   age                    17415 non-null  int64
#  8   previous_year_rating   17415 non-null  float64
#  9   length_of_service      17415 non-null  int64
#  10  KPIs_met_more_than_80  17415 non-null  int64
#  11  awards_won             17415 non-null  int64
#  12  avg_training_score     17415 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Step 4: Export the cleaned dataset as a .csv file: prefer UTF-8 encoding.

# %%
Clean_hr_data.to_csv('Clean_hr_data.csv', encoding='utf-8', index=False)
